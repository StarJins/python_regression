# %%
import pandas as pd
import numpy as np

files = list()
for x in range(1, 13):
    if len(str(x)) == 1:
        files.append("CALL_NDELIVERY_0%sMONTH.csv" % str(x))
    else:
        files.append("CALL_NDELIVERY_%sMONTH.csv" % str(x))

datas = list()
for file in files:
    data = pd.read_csv("C:/Users/Jintae/Desktop/python_regression/%s" % file)
    data = data.drop('시도', axis=1)
    datas.append(data)

print(datas)
# Out:
# [              일자 요일  시간대           업종   시군구   읍면동  통화건수
# 0       20180101  월    0  음식점-족발/보쌈전문   강남구   역삼동     5
# 1       20180101  월    0  음식점-족발/보쌈전문   강동구    길동     5
# 2       20180101  월    0  음식점-족발/보쌈전문   강북구    번동     5
# 3       20180101  월    0  음식점-족발/보쌈전문   강서구   가양동     5
# 4       20180101  월    0  음식점-족발/보쌈전문   강북구   미아동     5
# ...          ... ..  ...          ...   ...   ...   ...
# 137883  20180131  수   23           피자   동작구  신대방동     7
# 137884  20180131  수   23           피자   은평구   불광동     5
# 137885  20180131  수   23           피자    중구   수하동     5
# 137886  20180131  수   23           피자  서대문구   연희동     5
# 137887  20180131  수   23           피자    중구   신당동     5
#
# [137888 rows x 7 columns],               일자 요일  시간대           업종   시군구   읍면동  통화건수
# 0       20180201  목    0  음식점-족발/보쌈전문   강남구   논현동     5
# 1       20180201  목    0  음식점-족발/보쌈전문   강남구   역삼동     5
# 2       20180201  목    0  음식점-족발/보쌈전문   강서구  내발산동     5
# ...
